# %%
##### Audio Classification Using Machine Learning
#####dataset url https://urbansounddataset.weebly.com/urbansound8k.html

# %%
# !pip install librosa
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: librosa in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (0.10.1)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (1.24.3)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (1.11.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numba>=0.51.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (0.58.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (0.3.7)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (4.5.0)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (0.3)
# Requirement already satisfied: msgpack>=1.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from librosa) (1.0.7)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from numba>=0.51.0->librosa) (0.41.1)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from pooch>=1.0->librosa) (4.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from pooch>=1.0->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from pooch>=1.0->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from scikit-learn>=0.20.0->librosa) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shinjan saha\appdata\roaming\python\python311\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2023.7.22)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='../a0001.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 98FA-EFFA
#
#  Directory of c:\Users\SHINJAN SAHA\Desktop\Audio-Classification
#
# 23-12-2023  11:43    <DIR>          .
# 23-12-2023  11:48    <DIR>          ..
# 23-12-2023  11:54           276,774 Audio Classification EDA.ipynb
# 23-12-2023  11:43            35,823 LICENSE
# 23-12-2023  11:43           152,732 Part 2- Audio Classification Data Preprocessing And Model Creation.ipynb
# 23-12-2023  11:43           148,139 Part 2- Audio Classification Data Preprocessing.ipynb
# 23-12-2023  11:43                22 README.md
#                5 File(s)        613,490 bytes
#                2 Dir(s)  243,658,657,792 bytes free

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd

plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename)
librosa.display.waveshow(data, sr=sample_rate)
plt.title('Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
import IPython.display as ipd

plt.figure(figsize=(14, 5))
data, sample_rate = librosa.load(filename)
librosa.display.waveshow(data, sr=sample_rate)
plt.title('Waveform')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.show()

ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 2000

# %%
wave_audio
# Out:
# array([ -69, -135, -104, ..., -285, -257, -187], dtype=int16)

# %%
data
# Out:
# array([-0.00195204, -0.00237557, -0.00268287, ..., -0.00087867,
#        -0.00046927,  0.        ], dtype=float32)

# %%
import pandas as pd

metadata=pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[59], line 3
#       1 import pandas as pd
# ----> 3 metadata=pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
#       4 metadata.head(10)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'UrbanSound8K/metadata/UrbanSound8K.csv'

# %%
### Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# street_music        1000
# air_conditioner     1000
# jackhammer          1000
# engine_idling       1000
# drilling            1000
# children_playing    1000
# dog_bark            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: class, dtype: int64
